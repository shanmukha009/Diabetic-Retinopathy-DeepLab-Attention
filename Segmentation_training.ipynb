# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DDR/Segmentation
# Out:
# /content/drive/MyDrive/DDR/Segmentation

# %%
# !python preprocess.py --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation --convert_tif --check_integrity
# Out:
# Checking dataset integrity...
# Checking train images: 100% 383/383 [00:13<00:00, 27.76it/s]
# Checking valid images: 100% 149/149 [00:05<00:00, 25.38it/s]
# Checking test images: 100% 225/225 [00:07<00:00, 30.83it/s]
# No integrity issues found.
# Converting TIF masks to PNG...
# Found 3028 TIF files to convert
# Converting TIF to PNG: 100% 3028/3028 [1:03:04<00:00,  1.25s/it]
# Preprocessing completed!

# %%
# !python train.py --model deeplab --encoder resnet50 --batch_size 4 --epochs 100 --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 53 [Valid]:  50% 19/38 [00:17<00:17,  1.09it/s, loss=0.742]/content/drive/MyDrive/DDR/Segmentation/utils/losses.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight_tensor = torch.tensor(pos_weight, device=outputs.device)
# Epoch 53 [Valid]:  53% 20/38 [00:18<00:16,  1.07it/s, loss=0.742]/content/drive/MyDrive/DDR/Segmentation/utils/losses.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight_tensor = torch.tensor(pos_weight, device=outputs.device)
# ...

# %%
# !python train.py --model attention_unet --batch_size 4 --epochs 100 --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 65 [Valid]:  66% 25/38 [00:06<00:04,  3.02it/s, loss=0.708]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# Epoch 65 [Valid]:  71% 27/38 [00:06<00:02,  4.40it/s, loss=0.711]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# Epoch 65 [Valid]:  74% 28/38 [00:06<00:02,  4.49it/s, loss=0.716]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# Epoch 65 [Valid]:  76% 29/38 [00:07<00:02,  3.91it/s, loss=0.714]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# Epoch 65 [Valid]:  76% 29/38 [00:07<00:02,  3.91it/s, loss=0.712]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# Epoch 65 [Valid]:  82% 31/38 [00:07<00:01,  3.72it/s, loss=0.711]Resizing targets from torch.Size([512, 512]) to torch.Size([128, 128])
# ...

# %%
# !python evaluate.py --model deeplab --encoder resnet50 --checkpoint /content/drive/MyDrive/DDR/Segmentation/outputs/checkpoints/deeplab_best.pth --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation --split test --save_visualizations
# Out:
# Using device: cuda
# Found 225 images in test split
# Creating deeplab model...
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Model created, type: <class 'models.deeplab.DeepLabV3Plus'>
# Loading checkpoint from /content/drive/MyDrive/DDR/Segmentation/outputs/checkpoints/deeplab_best.pth
# Error with default loading: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# ...

# %%
# !python evaluate.py --model attention_unet --checkpoint /content/drive/MyDrive/DDR/Segmentation/outputs/checkpoints/attention_unet_best.pth  --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation --split test --save_visualizations
# Out:
# Using device: cuda
# Found 225 images in test split
# Creating attention_unet model...
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 234MB/s]
# Model created, type: <class 'models.attention_unet.AttentionUNet'>
# ...

# %%
# !python train.py --model unet --unet_base_channels 32 --epochs 100
# Out:
# 2025-09-12 17:25:36.726451: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-12 17:25:36.743665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757697936.765239    1328 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757697936.771734    1328 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python evaluate.py --model unet --unet_base_channels 32 --checkpoint /content/drive/MyDrive/DDR/Segmentation/outputs/checkpoints/unet_best.pth --data_root /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation --split test --save_visualizations
# Out:
# Using device: cuda
# Evaluating model: unet
# Loading test dataset from /content/drive/MyDrive/DDR/DDR-dataset/lesion_segmentation
# Found 225 images in test split
# Creating unet model...
# Created U-Net model:
#   - Base channels: 32
#   - Bilinear upsampling: True
#   - Dropout: False
# Model created, type: <class 'models.unet.UNet'>
# Loading checkpoint from /content/drive/MyDrive/DDR/Segmentation/outputs/checkpoints/unet_best.pth
# Error with default loading: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# ...
